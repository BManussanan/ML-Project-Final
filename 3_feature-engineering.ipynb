# %%
import pandas as pd

# %%
df_employee = pd.read_csv("2_training_data_employee.csv")
df_employee
# Out:
#            Age    DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# 0    42.000000  1368.000000         28.000000                 4.000000
# 1    25.000000   309.000000          2.000000                 3.000000
# 2    29.000000  1396.000000         10.000000                 3.000000
# 3    29.000000   986.000000          3.000000                 2.000000
# 4    50.000000   854.000000          1.000000                 4.000000
# ..         ...          ...               ...                      ...
# 469  26.008398   138.470606         16.173665                 3.834733
# 470  39.000000  1153.087248          2.984364                 3.953091
# 471  35.612788   359.576599         20.882993                 3.423401
# 472  24.318104   531.314693         11.159052                 3.394882
# 473  21.228370   504.085608          9.456740                 2.293488
#
#      HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# ...

# %%
df_employee.isnull().sum()
# Out:
# Age                                  0
# DailyRate                            0
# DistanceFromHome                     0
# EnvironmentSatisfaction              0
# HourlyRate                           0
# JobInvolvement                       0
# JobLevel                             0
# JobSatisfaction                      0
# MonthlyIncome                        0
# MonthlyRate                          0
# PercentSalaryHike                    0
# PerformanceRating                    0
# RelationshipSatisfaction             0
# StockOptionLevel                     0
# WorkLifeBalance                      0
# YearsAtCompany                       0
# YearsInCurrentRole                   0
# YearsSinceLastPromotion              0
# BusinessTravel_Non-Travel            0
# BusinessTravel_Travel_Frequently     0
# BusinessTravel_Travel_Rarely         0
# Department_Human Resources           0
# Department_Research & Development    0
# Department_Sales                     0
# ...
